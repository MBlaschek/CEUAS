# %%
# Super quick PLOTLY graph



import plotly.express as px
import pandas as pd 

path = '/srvfs/scratch/federico/databases_service2/MAURITIUS/'
file = 'hum_reduced/01_Vaisala.csv'


file_path = path + file 
DF = pd.read_csv(file_path)

fig = px.scatter(DF, x="hum", y="press")

# %%
fig.update_layout(
    width = 1200,
    height = 800,
    )

fig.show()
