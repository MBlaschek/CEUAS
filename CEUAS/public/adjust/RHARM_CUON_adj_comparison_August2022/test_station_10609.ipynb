# %%
import netCDF4 as nc
import pandas as pd 
f = '/scratch/das/federico/COP2_HARVEST_APRIL2022/era5_1/0-20000-0-10609_era5_1_harvested_era5.conv.??????.06597.txt.gz.nc'
ff = nc.Dataset(f, 'r')

# %%
ff
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): record(1), days(3), drange(1)
#     variables(dimensions): int32 dateindex(days, drange), int32 recordindex(record), int64 recordtimestamp(record)
#     groups: crs, era5fb, header_table, id_scheme, observations_table, observed_variable, sensor_configuration, source_configuration, station_configuration, station_configuration_codes, station_type, units, z_coordinate_type

# %%
dic = {} 
for v in ['date_time', 'observed_variable','z_coordinate', 'observation_value', 'latitude' , 'longitude']:
    dic[v] = ff['observations_table'][v][:]
# Out:
# <ipython-input-25-312fae48b223>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dic[v] = ff['observations_table'][v][:]

# %%
df = pd.DataFrame.from_dict(dic)
df['date_time'] = pd.to_datetime( df.date_time , unit='s',  origin=pd.Timestamp('1900-01-01')  )

# %%
df
# Out:
#              date_time  observed_variable  z_coordinate  observation_value  \
# 0  1989-06-12 06:00:00                117  60069.828125       41190.000000
# 1  1989-06-12 06:00:00                106  61260.773438         335.000000
# 2  1989-06-12 06:00:00                107  61260.773438          13.000000
# 3  1989-06-12 06:00:00                139  61260.773438           5.494038
# 4  1989-06-12 06:00:00                140  61260.773438         -11.782001
# 5  1989-06-12 06:00:00                117  78530.453125       20590.000000
# 6  1989-06-12 06:00:00                106  79657.062500         350.000000
# 7  1989-06-12 06:00:00                107  79657.062500          10.000000
# 8  1989-06-12 06:00:00                139  79657.062500           1.736482
# 9  1989-06-12 06:00:00                140  79657.062500          -9.848078
# 10 1989-06-12 06:00:00                117  94330.804688        5880.000000
# 11 1989-06-12 06:00:00                106  95447.914062          20.000000
# 12 1989-06-12 06:00:00                107  95447.914062           3.000000
# 13 1989-06-12 06:00:00                139  95447.914062          -1.026060
# 14 1989-06-12 06:00:00                140  95447.914062          -2.819078
# 15 1989-06-12 06:00:00                117  97777.281250        2940.000000
# 16 1989-06-12 06:00:00                106  98899.843750         200.000000
# 17 1989-06-12 06:00:00                107  98899.843750           3.000000
# 18 1989-06-12 06:00:00                139  98899.843750           1.026060
# 19 1989-06-12 06:00:00                140  98899.843750           2.819078
#
#      latitude  longitude
# 0   49.799999       6.45
# 1   49.799999       6.45
# 2   49.799999       6.45
# 3   49.799999       6.45
# 4   49.799999       6.45
# 5   49.799999       6.45
# 6   49.799999       6.45
# 7   49.799999       6.45
# 8   49.799999       6.45
# 9   49.799999       6.45
# 10  49.799999       6.45
# 11  49.799999       6.45
# 12  49.799999       6.45
# 13  49.799999       6.45
# 14  49.799999       6.45
# 15  49.799999       6.45
# 16  49.799999       6.45
# 17  49.799999       6.45
# 18  49.799999       6.45
# 19  49.799999       6.45

# %%
merged = '/mnt/users/scratch/leo/scratch/converted_v8/0-20000-0-10609_CEUAS_merged_v1.nc'
ff = nc.Dataset(merged, 'r')
dic = {} 
for v in ['date_time', 'observed_variable','z_coordinate', 'z_coordinate_type', 'observation_value', 'latitude' , 'longitude', 'observation_id']:
    dic[v] = ff['observations_table'][v][:]
ids = [b''.join(i) for i in dic['observation_id'] ]
dic['observation_id'] = ids
df = pd.DataFrame.from_dict(dic)
df['date_time'] = pd.to_datetime( df.date_time , unit='s',  origin=pd.Timestamp('1900-01-01')  )
# Out:
# <ipython-input-39-863a25a821c2>:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dic[v] = ff['observations_table'][v][:]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-863a25a821c2> in <module>
#       3 dic = {}
#       4 for v in ['date_time', 'observed_variable','z_coordinate', 'z_cooridnate_type', 'observation_value', 'latitude' , 'longitude', 'observation_id']:
# ----> 5     dic[v] = ff['observations_table'][v][:]
#       6 ids = [b''.join(i) for i in dic['observation_id'] ]
#       7 dic['observation_id'] = ids
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__getitem__()
#
# IndexError: z_cooridnate_type not found in /observations_table

# %%
df = df.sort_values( by=['date_time'])

# %%
df
# Out:
#              date_time  observed_variable  z_coordinate  observation_value  \
# 0  1924-01-07 13:00:00                106   1392.544312       0.000000e+00
# 49 1924-01-07 13:00:00                140  14709.974609       4.619398e+00
# 50 1924-01-07 13:00:00                140  19613.300781       0.000000e+00
# 51 1924-01-07 13:00:00                140  29419.949219      -2.622683e-07
# 52 1924-01-07 13:00:00                140  39226.601562      -2.771638e+00
# 46 1924-01-07 13:00:00                140   1392.544312       0.000000e+00
# 32 1924-01-07 13:00:00                139   1392.544312       0.000000e+00
# 33 1924-01-07 13:00:00                139   4903.325195       1.530734e+00
# 34 1924-01-07 13:00:00                139   9806.650391      -4.988818e+00
# 20 1924-01-07 13:00:00                107  39226.601562       3.000000e+00
# 19 1924-01-07 13:00:00                107  29419.949219       3.000000e+00
# 18 1924-01-07 13:00:00                107  19613.300781       0.000000e+00
# 17 1924-01-07 13:00:00                107  14709.974609       5.000000e+00
# 16 1924-01-07 13:00:00                107   9806.650391       6.000000e+00
# 48 1924-01-07 13:00:00                140   9806.650391       3.333421e+00
# 15 1924-01-07 13:00:00                107   4903.325195       4.000000e+00
# 35 1924-01-07 13:00:00                139  14709.974609       1.913417e+00
# 36 1924-01-07 13:00:00                139  19613.300781       0.000000e+00
# 37 1924-01-07 13:00:00                139  29419.949219      -3.000000e+00
# 38 1924-01-07 13:00:00                139  39226.601562       1.148050e+00
# 6  1924-01-07 13:00:00                106  39226.601562       3.375000e+02
# 5  1924-01-07 13:00:00                106  29419.949219       9.000000e+01
# 4  1924-01-07 13:00:00                106  19613.300781       0.000000e+00
# 3  1924-01-07 13:00:00                106  14709.974609       2.025000e+02
# 2  1924-01-07 13:00:00                106   9806.650391       1.237500e+02
# 1  1924-01-07 13:00:00                106   4903.325195       2.025000e+02
# 14 1924-01-07 13:00:00                107   1392.544312       0.000000e+00
# 47 1924-01-07 13:00:00                140   4903.325195       3.695518e+00
# 39 1927-11-13 10:00:00                139   4903.325195      -2.296102e+00
# 40 1927-11-13 10:00:00                139   9806.650391      -3.923141e+00
# 41 1927-11-13 10:00:00                139  19613.300781      -5.656855e+00
# 21 1927-11-13 10:00:00                107   4903.325195       6.000000e+00
# 23 1927-11-13 10:00:00                107  19613.300781       8.000000e+00
# 22 1927-11-13 10:00:00                107   9806.650391       4.000000e+00
# 54 1927-11-13 10:00:00                140   9806.650391      -7.803610e-01
# 55 1927-11-13 10:00:00                140  19613.300781      -5.656854e+00
# 9  1927-11-13 10:00:00                106  19613.300781       4.500000e+01
# 8  1927-11-13 10:00:00                106   9806.650391       7.875000e+01
# 7  1927-11-13 10:00:00                106   4903.325195       2.250000e+01
# 53 1927-11-13 10:00:00                140   4903.325195      -5.543277e+00
# 45 1989-06-12 06:00:00                139  98899.843750       1.026060e+00
# 56 1989-06-12 06:00:00                140  61260.773438      -1.178200e+01
# 57 1989-06-12 06:00:00                140  79657.062500      -9.848078e+00
# 44 1989-06-12 06:00:00                139  95447.914062      -1.026060e+00
# 29 1989-06-12 06:00:00                117  78530.453125       2.059000e+04
# 42 1989-06-12 06:00:00                139  61260.773438       5.494038e+00
