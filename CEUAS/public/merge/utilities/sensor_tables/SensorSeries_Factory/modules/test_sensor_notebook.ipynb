# %%
import sys
sys.path.append('modules')

from sensor_functions import *
from plot_functions_sensor import *

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1150e3acdbba> in <module>
# ----> 1 from sensor_functions import *
#       2 from plot_functions_sensor import *
#       3
#       4 pd.set_option('display.max_rows', None)
#       5 pd.set_option('display.max_columns', None)
#
# /mnt/users/staff/federico/GitHub/CEUAS_master_SEPTEMBER2021/CEUAS/CEUAS/public/merge/utilities/sensor_tables/SensorSeries_Factory/modules/sensor_functions.py in <module>
#     419
#     420 # Loading sensor configuration
# --> 421 sensor = Sensor()
#     422
#     423 # Merged file source (if data not already available)
#
# /mnt/users/staff/federico/GitHub/CEUAS_master_SEPTEMBER2021/CEUAS/CEUAS/public/merge/utilities/sensor_tables/SensorSeries_Factory/modules/sensor_functions.py in __init__(self)
#     146     def __init__(self):
#     147         # sensor configuration
# --> 148         sensor_conf = pd.read_csv('sensor_configuration_all.csv', sep='\t',  index_col=0)
#     149
#     150         # add a converted column (to strings)
#
# ~/.conda/envs/Work/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/.conda/envs/Work/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/.conda/envs/Work/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/.conda/envs/Work/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/.conda/envs/Work/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sensor_configuration_all.csv'

# %%
# Select Station
station = '0-20001-0-11035'

# %%
# getting the data
data_clean_all, all_sensor_station, data_all_wmo = get_data(station, force_create=False)

# %%
data_clean_all
# Out:
#               date_time sensor_id  value source  \
# 0   1905-04-04 06:00:00  N??       1      SCH
# 1   1930-05-21 13:00:00  DDD       1      SCH
# 2   1950-01-01 03:00:00  DF1       1      SCH
# 3   1952-07-09 15:00:00  MDF       1      SCH
# 4   1952-10-05 03:00:00  DF2       1      SCH
# 5   1971-02-22 00:00:00  RK2       1      SCH
# 6   1975-09-12 00:00:00  XXX       1      SCH
# 7   1991-10-31 23:00:00  RR2       1      SCH
# 8   1992-03-25 11:00:00  RRn       1      SCH
# 9   1992-03-25 23:00:00  RR2       1      SCH
# 17  1992-03-29 23:00:00  VDV       1      SCH
# 18  1992-03-30 05:00:00  RR2       1      SCH
# 19  1992-03-30 11:00:00  VDV       1      SCH
# 22  1992-05-06 10:00:00  RR2       1      SCH
# 23  1992-05-06 17:00:00  VDV       1      SCH
# 25  1992-09-04 11:00:00  VDV       1      SCH
# 26  1993-02-28 23:00:00  VDT       1      SCH
# 27  1993-03-11 05:00:00  VDV       1      SCH
# 28  1993-03-11 11:00:00  VDT       1      SCH
# 30  1993-03-16 05:00:00  VDT       1      SCH
# 31  1993-03-23 11:00:00  VDV       1      SCH
# 32  1993-03-23 17:00:00  VDT       1      SCH
# 33  1993-09-21 18:00:00  VDV       1      SCH
# 34  1993-10-17 11:00:00  VDT       1      SCH
# 35  1993-10-17 23:00:00  VDV       1      SCH
# 36  1993-10-20 17:00:00  VDT       1      SCH
# 37  1994-02-14 12:00:00  VDV       1      SCH
# 38  1994-02-14 23:00:00  VDT       1      SCH
# 39  1994-03-17 05:00:00  VDV       1      SCH
# 41  1994-03-19 18:00:00  VDV       1      SCH
# 42  1994-03-23 11:00:00  VDT       1      SCH
# 43  1994-05-09 11:00:00  VDV       1      SCH
# 44  1994-05-09 18:00:00  VDT       1      SCH
# 45  1994-05-09 23:00:00  VDV       1      SCH
# 46  1994-05-10 05:00:00  VDT       1      SCH
# 49  1994-05-11 05:00:00  VDV       1      SCH
# 50  1994-05-11 11:00:00  VDT       1      SCH
# 51  1994-05-24 11:00:00  VDV       1      SCH
# 52  1994-06-06 11:00:00  VDT       1      SCH
# 55  1994-06-08 17:00:00  VDV       1      SCH
# 56  1994-06-09 18:00:00  VDT       1      SCH
# 57  1994-06-09 23:00:00  VDV       1      SCH
# 61  1994-09-08 11:00:00  VDV       1      SCH
# 63  2004-06-30 23:00:00  VNg       1      SCH
# 64  2004-08-04 11:00:00  VDG       1      SCH
# 65  2004-08-04 17:00:00  VNg       1      SCH
# 66  2006-03-10 23:00:00  VDG       1      SCH
# 67  2006-03-11 06:00:00  VNg       1      SCH
# 68  2013-01-01 05:00:00  80        2      WMO
# 69  2017-03-21 16:50:04  123       2      WMO
# 70  2019-05-07 23:00:36  114       2      WMO
# 71  2019-05-08 04:50:55  123       2      WMO
# 72  1960-01-01 00:00:00  IGRA2     3      IGRA2
#
#                                                                                                                                                   comment  \
# 0     N?? exact type insufficiently documented
# 1     DDD Germany Duckert PT radiosonde {1930}^ <F=V5-10FB,P=D,T=BC>
# 2     DF1 East Germany Freiberg radiosonde {1948}^ <F=V26.75HB,P=A,T=B,U=H>
# 3     MDF Mixed Germany Freiberg (DF1) and Freiberg double radiation shield (DF2)^ Station 10393 in 1951 and 1952 and possibly other East German stations
# 4     DF2 East Germany Freiberg double radiation shield radiosonde {1951}^ (I=F, W1=04, W2=10 ends 198607 but may have been reassigned
# 5     RK2 USSR RKZ-2 radiosonde {1967}^ (W2=20, T=304) <F=V1780PB,P=B,T=TR,U=G>
# 6     XXX Reject all obs with this station ID in this period^ misidentified or erroneous observations which should be rejected
# 7     RR2 USSR MARS-2 unspecified model {1983}^ (T=223) temperature, humidity, and winds <F=T1780PL,P=0,T=TR,U=G,W=Ta>
# 8     RRn USSR MARS-2-2 radiosonde no correction 31313=02903^
# 9     RR2 USSR MARS-2 unspecified model {1983}^ (T=223) temperature, humidity, and winds <F=T1780PL,P=0,T=TR,U=G,W=Ta>
# 17    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 18    RR2 USSR MARS-2 unspecified model {1983}^ (T=223) temperature, humidity, and winds <F=T1780PL,P=0,T=TR,U=G,W=Ta>
# 19    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 22    RR2 USSR MARS-2 unspecified model {1983}^ (T=223) temperature, humidity, and winds <F=T1780PL,P=0,T=TR,U=G,W=Ta>
# 23    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 25    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 26    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 27    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 28    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 30    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 31    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 32    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 33    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 34    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 35    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 36    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 37    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 38    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 39    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 41    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 42    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 43    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 44    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 45    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 46    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 49    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 50    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 51    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 52    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 55    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 56    VDT Vaisala RS80 PC Cora auto corr, ranging wind 31313=46203^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,W=Ta>
# 57    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 61    VDV Vaisala RS80 PC Cora auto corr, Omega wind 31313=46205^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=O>
# 63    VNg Vaisala RS92 DigiCORA III auto corr, GPS wind 31313=48008^ <F=T400-406DL,P=Sc,T=Wc,U=2Ah,N=G>
# 64    VDG Vaisala RS80 PC Cora auto corr, GPS wind 31313=46208^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=G>
# 65    VNg Vaisala RS92 DigiCORA III auto corr, GPS wind 31313=48008^ <F=T400-406DL,P=Sc,T=Wc,U=2Ah,N=G>
# 66    VDG Vaisala RS80 PC Cora auto corr, GPS wind 31313=46208^ <F=T403FL or 1680AL,P=Ac,T=CB,U=A,N=G>
# 67    VNg Vaisala RS92 DigiCORA III auto corr, GPS wind 31313=48008^ <F=T400-406DL,P=Sc,T=Wc,U=2Ah,N=G>
# 68  Vaisala RS92/Digicora III (Finland)
# 69  Vaisala RS41/DigiCORA MW41 (Finland)
# 70  Vaisala RS92/DigiCORA MW41 (Finland)
# 71  Vaisala RS41/DigiCORA MW41 (Finland)
# 72  USING SONDE MODEL , I1 , E GERMANY FREIBERG UNSPECIFIED
#
#      moment
# 0   morning
# 1   day
# 2   night
# 3   day
# 4   night
# 5   night
# 6   night
# 7   night
# 8   day
# 9   night
# 17  night
# 18  morning
# 19  day
# 22  day
# 23  evening
# 25  day
# 26  night
# 27  morning
# 28  day
# 30  morning
# 31  day
# 32  evening
# 33  evening
# 34  day
# 35  night
# 36  evening
# 37  day
# 38  night
# 39  morning
# 41  evening
# 42  day
# 43  day
# 44  evening
# 45  night
# 46  morning
# 49  morning
# 50  day
# 51  day
# 52  day
# 55  evening
# 56  evening
# 57  night
# 61  day
# 63  night
# 64  day
# 65  evening
# 66  night
# 67  morning
# 68  morning
# 69  evening
# 70  night
# 71  morning
# 72  night

# %%
# Initialize Plot Class
save_fig = False
plot = Plot(station.split('_')[-1], save=save_fig)

# %%
# making the plots
series = plot.time_series( data_clean_all, label='')
table = plot.sensor_table( all_sensor_station)
wmo_bar = plot.wmo_bar_plot(data_all_wmo)

# %%
#data_all_wmo

# %%
#w = data_clean_all[data_clean_all.source=="WMO"]

# %%
#data_clean_all

# %%
#table = plot.sensor_table( all_sensor_station)
#table.show()

# %%
series.show()

# %%
table = plot.sensor_table( all_sensor_station)
table.show()

# %%
wmo_bar.show()
