# %%
import numpy
import numpy as np
import pandas as pd
import sys, glob
import urllib3
import h5py
import cdsapi, zipfile, os, time
import warnings
import shutil
import xarray
from datetime import date
warnings.filterwarnings('ignore')
import pycountry
sys.path.append(os.getcwd()+'/../cds-backend/code/')
import cds_eua3 as eua
# import numbaprocess
import copy
import glob
from numba import njit
import pandas
import glob
import pickle
import matplotlib


def request(rqdict, source, remove_file=True):
    t0 = time.time()

    c = cdsapi.Client()
    r = c.retrieve(
        source,rqdict)
    print('Request took: ' + str(time.time() - t0) + ' seconds')
    if True:
        r.download(target='download.zip')
        assert os.stat('download.zip').st_size == r.content_length, "Downloaded file is incomplete"
    z = zipfile.ZipFile('download.zip')
    z.extractall(path='./download/')
    z.close()
    return
    
    
#     files = glob.glob('./download/*.nc')
#     print(files)
#     # nc
#     if 'nc' in files[0].split('.')[-1]:
#         ds = xarray.open_dataset(files[0])            
#         data = ds.to_dataframe()
#         for i in files[1:]:
#             ds = xarray.open_dataset(i)            
#             data = data.append(ds.to_dataframe())
#     # csv
#     else:
#         data = pd.read_csv(files[0], header=12, index_col=False)
#         for i in files[1:]:
#             ds = pd.read_csv(i, header=12, index_col=False)  
#             data = data.append(ds.to_dataframe())
            
#     os.remove('download.zip')
#     if remove_file:
#         try:
#            shutil.rmtree('./download/')
#         except:
#            print('Error while deleting directory')

#     return data

igra = 'insitu-observations-igra-baseline-network'

yr = 2000
out = request({
    'source': 'IGRA_H',# 'IGRA'
    'variable':['air_temperature'],
    'period':str(yr)+'-01-01/'+str(yr+1)+'-01-01',
#     'format': 'csv-lev.zip', # no format = .nc
    'station_name':'AUM00011035',
},igra, remove_file=False)
# Out:
# 2022-08-19 12:03:23,007 INFO Welcome to the CDS
# 2022-08-19 12:03:23,008 INFO Sending request to https://cds-test.copernicus-climate.eu/api/v2/resources/insitu-observations-igra-baseline-network
# 2022-08-19 12:03:23,047 INFO Request is queued
# 2022-08-19 12:03:24,082 INFO Request is running
# 2022-08-19 12:03:31,318 INFO Request is completed
# 2022-08-19 12:03:31,320 INFO Downloading https://cds-test-download-0000.copernicus-climate.eu/cache-compute-0000/cache/data0/adaptor.insitu_reference.retrieve-1660903409.7185173-17750-2-66d00b1c-7e3c-48ea-abca-72800658502e.zip to download.zip (732.5K)
# Request took: 8.339380741119385 seconds
# 2022-08-19 12:03:31,532 INFO Download rate 3.4M/s

# %%
stations = pickle.load( open( "../intercomparisons/stations.p", "rb" ))

# %%
stations
# Out:
#       station_name  location_longitude  location_latitude
# 0      KRM00091487           -159.3670             3.8500
# 1      CHM00055664             87.0830            28.6330
# 2      CHM00056444             98.8830            28.4500
# 3      BMM00048062             92.8830            20.1330
# 4      CHM00057290            114.0500            32.9670
# ...            ...                 ...                ...
# 36592  INM00043110             73.3333            16.9833
# 37459  INM00042165             73.3000            28.0000
# 37460  INM00042328             70.9167            26.9000
# 37461  RPM00098233            121.7525            17.6375
# 37462  USM00074003           -112.9333            40.1667
#
# [1494 rows x 3 columns]
