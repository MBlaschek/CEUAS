# %%
import pandas as pd
import numpy as np
import os, glob, sys
sys.path.append(os.getcwd()+'/../cds-backend/code/')
import cds_eua4 as eua
import trajectory
import h5py

import ray
import time

import multiprocessing
from functools import partial

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return array[idx]

def datetime_to_seconds(dates, ref='1900-01-01T00:00:00'):
    """ from datetime64 to seconds since 1900-01-01 00:00:00"""
    return ((dates - np.datetime64(ref)) / np.timedelta64(1, 's')).astype(np.int64)

def seconds_to_datetime(seconds, ref='1900-01-01'):
    """ from seconds to datetime64 """
    seconds = np.asarray(seconds)
    return pd.to_datetime(seconds, unit='s', origin=ref)

# %%
@ray.remote
def create_disp_files(s):
    try:
        statid = (s.split("-")[-1])
        print(statid)
        conv_file = glob.glob('/mnt/users/scratch/leo/scratch/converted_v9/newindex/*'+statid+'*')[0]
        dt_from = datetime_to_seconds(np.datetime64('2020-01-01'))
        dt_to = datetime_to_seconds(np.datetime64('2021-12-31'))

        df_dict = {}
        h_df_dict = {}

        with h5py.File(conv_file, 'r') as file:
            rts = file['recordindices']['recordtimestamp'][:]
            idx = np.where(np.logical_and((rts >= dt_from), (rts <= dt_to)))[0]
            plevs = [1000,2000,3000,5000,7000,10000,15000,20000,25000,30000,40000,50000,70000,85000,92500,100000]
            idx_d = {}
            var_d = {'air_temperature':'126', 'relative_humidity':'138', 'geopotential':'117', 'eastward_wind_speed':'139', 'northward_wind_speed':'140', 'dew_point': '137', 'specific_humidity':'39'}
            for i in var_d:
                idx_d[i] = file['recordindices'][var_d[i]][idx]

            masks = {}
            for i in idx_d:
                masks[i] = file['observations_table']['z_coordinate'][idx_d[i][0]:idx_d[i][-1]]
                masks[i] = np.isin(masks[i],plevs)

            mask = masks['air_temperature']
            t_idx = idx_d['air_temperature']
            df_dict['z_coordinate'] = list(file['observations_table']['z_coordinate'][t_idx[0]:t_idx[-1]][mask])
            df_dict['date_time'] = seconds_to_datetime(list(file['observations_table']['date_time'][t_idx[0]:t_idx[-1]][mask]))
            df_dict['latitude'] = list(file['observations_table']['latitude'][t_idx[0]:t_idx[-1]][mask])
            df_dict['longitude'] = list(file['observations_table']['longitude'][t_idx[0]:t_idx[-1]][mask])
            repid = np.asarray(file['observations_table']['report_id'][t_idx[0]:t_idx[-1]][mask])
            df_dict['report_id'] = list(repid.view('|S{}'.format(repid.shape[1])).flatten().astype(str))
            df_dict['RASE_bias_estimate'] = list(file['advanced_homogenisation']['RASE_bias_estimate'][t_idx[0]:t_idx[-1]][mask])
            # df_dict['latitude_displacement'] = list(file['advanced_homogenisation']['latitude_displacement'][t_idx[0]:t_idx[-1]][mask])
            # df_dict['longitude_displacement'] = list(file['advanced_homogenisation']['longitude_displacement'][t_idx[0]:t_idx[-1]][mask])
            # df_dict['time_since_launch'] = list(file['advanced_homogenisation']['time_since_launch'][t_idx[0]:t_idx[-1]][mask])
            df_dict['air_temperature'] = list(file['observations_table']['observation_value'][t_idx[0]:t_idx[-1]][mask])

            df_dict_d = {}
            for i in masks:
                if i != 'air_temperature':
                    df_dict_d[i] = {}
            for i in masks:
                if i != 'air_temperature':
                    df_dict_d[i]['z_coordinate'] = list(file['observations_table']['z_coordinate'][idx_d[i][0]:idx_d[i][-1]][masks[i]])
                    df_dict_d[i]['date_time'] = seconds_to_datetime(list(file['observations_table']['date_time'][idx_d[i][0]:idx_d[i][-1]][masks[i]]))
                    df_dict_d[i][i] = list(file['observations_table']['observation_value'][idx_d[i][0]:idx_d[i][-1]][masks[i]])            

            first = True
            for i in ['air_temperature', 'eastward_wind_speed', 'northward_wind_speed']:
                if first:
                    out_df = pd.DataFrame.from_dict(df_dict)
                    # print('out_df')
                    # display(out_df)
                    # out_df = out_df.rename(columns={"observation_value": i})
                    # out_df = out_df.drop(['variable'], axis=1)
                    first = False
                else:
                    new = pd.DataFrame.from_dict(df_dict_d[i])
                    for drp in ["data_policy_licence", "RAOBCORE_bias_estimate", "latitude", "longitude", "primary_id", "report_id", "variable"]:
                        try:
                            new = new.drop([drp], axis=1)
                        except: pass
                    # new = new.rename(columns={'observation_value':i})
                    out_df = pd.merge(out_df, new, on=['date_time', 'z_coordinate'], how='inner')
            for i in ['dew_point', 'geopotential', 'relative_humidity', 'specific_humidity']:
                new = pd.DataFrame.from_dict(df_dict_d[i])
                print(i, len(new))
                for drp in ["data_policy_licence", "RAOBCORE_bias_estimate", "latitude", "longitude", "primary_id", "report_id", "variable"]:
                    try:
                        new = new.drop([drp], axis=1)
                    except: pass
                new = new.rename(columns={'observation_value':i})
                out_df = pd.merge(out_df, new, on=['date_time', 'z_coordinate'], how='left')

            dfj = out_df    
            # print('dfj')
            # display(dfj)

            latds = []
            londs = []
            rtss = []
            for i in dfj.report_id.unique():
                dfi = dfj[dfj.report_id == i]
                dfi = dfi.sort_values(by=['z_coordinate'], ascending=False)
                latd, lond, us, vs, rts = trajectory.trajectory(lat = dfi.latitude.iloc[0], lon = dfi.longitude.iloc[0], u = np.array(dfi.eastward_wind_speed), v = np.array(dfi.northward_wind_speed), pressure= np.array(dfi.z_coordinate), temperature=np.array(dfi.air_temperature))
                latds += (latd[::-1])
                londs += (lond[::-1])
                rtss += (rts[::-1])
            dfj['latitude_displacement'] = latds
            dfj['longitude_displacement'] = londs
            dfj['seconds_since_launche'] = rtss
            if len(dfj) > 0:
                dfj.to_csv("./displacement_files_no_licience_2020/"+str(statid)+"_displacements_2020_2022.csv")

    except:
        pass

# %%
stats = list(pd.read_csv(glob.glob('RAOBS_EUR-11.csv')[0]).statid)
ray.shutdown()
ray.init(num_cpus=20)
result_ids = []
for i in stats:
    result_ids.append(create_disp_files.remote(i))
results = ray.get(result_ids)
ray.shutdown()
# Out:
# 2023-02-02 12:14:29,896	INFO worker.py:1528 -- Started a local Ray instance.
# (create_disp_files pid=1452262) 08190
# (create_disp_files pid=1452267) 08023
# (create_disp_files pid=1452254) 08001
# (create_disp_files pid=1452264) 07761
# (create_disp_files pid=1452256) 07510
# (create_disp_files pid=1452248) 07481
# (create_disp_files pid=1452261) 07145
# (create_disp_files pid=1452265) 06458
# (create_disp_files pid=1452255) 06181
# (create_disp_files pid=1452266) 03769
# (create_disp_files pid=1452259) 03743
# (create_disp_files pid=1452252) 03316
# (create_disp_files pid=1452257) 03238
# (create_disp_files pid=1452258) 03171
# (create_disp_files pid=1452263) 02963
# (create_disp_files pid=1452250) 02935
# (create_disp_files pid=1452260) 02836
# (create_disp_files pid=1452253) 02591
# (create_disp_files pid=1452251) 02365
# (create_disp_files pid=1452249) 02185
# (create_disp_files pid=1452248) 10046
# (create_disp_files pid=1452252) 08430
# (create_disp_files pid=1452258) 10184
# (create_disp_files pid=1452250) 10200
# (create_disp_files pid=1452248) 10339
# (create_disp_files pid=1452248) 10439
# (create_disp_files pid=1452248) 10818
# (create_disp_files pid=1452248) 11120
# (create_disp_files pid=1452255) 10304
# (create_disp_files pid=1452266) 10771
# (create_disp_files pid=1452250) 10238
# (create_disp_files pid=1452249) dew_point 23
# (create_disp_files pid=1452249) geopotential 26
# (create_disp_files pid=1452249) relative_humidity 23
# (create_disp_files pid=1452249) specific_humidity 23
# (create_disp_files pid=1452249) 11240
# (create_disp_files pid=1452253) dew_point 1712
# (create_disp_files pid=1452253) geopotential 1847
# (create_disp_files pid=1452253) relative_humidity 1712
# (create_disp_files pid=1452253) specific_humidity 1712
# (create_disp_files pid=1452265) dew_point 9476
# (create_disp_files pid=1452265) geopotential 13679
# (create_disp_files pid=1452265) relative_humidity 10227
# (create_disp_files pid=1452265) specific_humidity 9466
# (create_disp_files pid=1452253) 12120
# (create_disp_files pid=1452259) dew_point 7425
# (create_disp_files pid=1452259) geopotential 8653
# (create_disp_files pid=1452259) relative_humidity 7425
# (create_disp_files pid=1452259) specific_humidity 7425
# (create_disp_files pid=1452257) dew_point 13238
# (create_disp_files pid=1452257) geopotential 14018
# (create_disp_files pid=1452257) relative_humidity 13238
# (create_disp_files pid=1452257) specific_humidity 13238
# (create_disp_files pid=1452248) dew_point 7644
# (create_disp_files pid=1452248) geopotential 8648
# (create_disp_files pid=1452251) 12374
# (create_disp_files pid=1452248) relative_humidity 7644
# (create_disp_files pid=1452248) specific_humidity 7644
# (create_disp_files pid=1452249) dew_point 8862
# (create_disp_files pid=1452249) geopotential 9962
# (create_disp_files pid=1452249) relative_humidity 8862
# (create_disp_files pid=1452249) specific_humidity 8862
# (create_disp_files pid=1452262) dew_point 18775
# (create_disp_files pid=1452262) geopotential 18790
# (create_disp_files pid=1452262) relative_humidity 18748
# (create_disp_files pid=1452255) dew_point 12764
# (create_disp_files pid=1452255) geopotential 16688
# (create_disp_files pid=1452255) relative_humidity 12776
# (create_disp_files pid=1452255) specific_humidity 12764
# (create_disp_files pid=1452262) specific_humidity 18748
# (create_disp_files pid=1452261) dew_point 22042
# (create_disp_files pid=1452261) geopotential 22105
# (create_disp_files pid=1452261) relative_humidity 22056
# (create_disp_files pid=1452261) specific_humidity 22040
# (create_disp_files pid=1452252) dew_point 17438
# (create_disp_files pid=1452252) geopotential 17438
# (create_disp_files pid=1452252) relative_humidity 17438
# (create_disp_files pid=1452252) specific_humidity 17438
# (create_disp_files pid=1452259) 12425
# (create_disp_files pid=1452256) dew_point 23845
# (create_disp_files pid=1452256) geopotential 23920
# (create_disp_files pid=1452264) dew_point 25008
# (create_disp_files pid=1452264) geopotential 25070
# (create_disp_files pid=1452264) relative_humidity 25031
# (create_disp_files pid=1452264) specific_humidity 25000
# (create_disp_files pid=1452256) relative_humidity 23835
# (create_disp_files pid=1452256) specific_humidity 23835
# (create_disp_files pid=1452248) 14240
# (create_disp_files pid=1452249) 15480
# (create_disp_files pid=1452249) 16113
# (create_disp_files pid=1452248) dew_point 22200
# (create_disp_files pid=1452248) geopotential 22881
# (create_disp_files pid=1452248) relative_humidity 22200
# (create_disp_files pid=1452248) specific_humidity 22200
# (create_disp_files pid=1452254) dew_point 19722
# (create_disp_files pid=1452254) geopotential 20484
# (create_disp_files pid=1452254) relative_humidity 19722
# (create_disp_files pid=1452254) specific_humidity 19722
# (create_disp_files pid=1452265) 16716
# (create_disp_files pid=1452257) 16622
# (create_disp_files pid=1452260) dew_point 26867
# (create_disp_files pid=1452260) geopotential 29161
# (create_disp_files pid=1452260) relative_humidity 26867
# (create_disp_files pid=1452260) specific_humidity 26867
# (create_disp_files pid=1452253) dew_point 20910
# (create_disp_files pid=1452253) geopotential 21165
# (create_disp_files pid=1452267) dew_point 19635
# (create_disp_files pid=1452267) geopotential 20282
# (create_disp_files pid=1452267) relative_humidity 19635
# (create_disp_files pid=1452267) specific_humidity 19635
# (create_disp_files pid=1452253) relative_humidity 20909
# (create_disp_files pid=1452253) specific_humidity 20909
# (create_disp_files pid=1452258) dew_point 22970
# (create_disp_files pid=1452258) geopotential 23289
# (create_disp_files pid=1452258) relative_humidity 22970
# (create_disp_files pid=1452258) specific_humidity 22970
# (create_disp_files pid=1452251) dew_point 22318
# (create_disp_files pid=1452251) geopotential 22943
# (create_disp_files pid=1452251) relative_humidity 22318
# (create_disp_files pid=1452251) specific_humidity 22318
# (create_disp_files pid=1452263) dew_point 40403
# (create_disp_files pid=1452263) geopotential 42914
# (create_disp_files pid=1452255) 16754
# (create_disp_files pid=1452263) relative_humidity 40403
# (create_disp_files pid=1452263) specific_humidity 40403
# (create_disp_files pid=1452265) dew_point 10571
# (create_disp_files pid=1452265) geopotential 10815
# (create_disp_files pid=1452265) relative_humidity 10570
# (create_disp_files pid=1452265) specific_humidity 10570
# (create_disp_files pid=1452262) 22113
# (create_disp_files pid=1452252) 17095
# (create_disp_files pid=1452259) dew_point 22725
# (create_disp_files pid=1452259) geopotential 23475
# (create_disp_files pid=1452259) relative_humidity 22725
# (create_disp_files pid=1452259) specific_humidity 22725
# (create_disp_files pid=1452252) dew_point 15526
# (create_disp_files pid=1452257) dew_point 15096
# (create_disp_files pid=1452257) geopotential 15461
# (create_disp_files pid=1452257) relative_humidity 15096
# (create_disp_files pid=1452257) specific_humidity 15096
# (create_disp_files pid=1452252) geopotential 22101
# (create_disp_files pid=1452252) relative_humidity 15111
# (create_disp_files pid=1452252) specific_humidity 15111
# (create_disp_files pid=1452261) 22217
# (create_disp_files pid=1452249) dew_point 20496
# (create_disp_files pid=1452249) geopotential 22452
# (create_disp_files pid=1452249) relative_humidity 20585
# (create_disp_files pid=1452249) specific_humidity 20495
# (create_disp_files pid=1452255) dew_point 11518
# (create_disp_files pid=1452255) geopotential 11856
# (create_disp_files pid=1452255) relative_humidity 11518
# (create_disp_files pid=1452255) specific_humidity 11518
# (create_disp_files pid=1452256) 22271
# (create_disp_files pid=1452254) 22543
# (create_disp_files pid=1452265) 22820
# (create_disp_files pid=1452262) dew_point 19035
# (create_disp_files pid=1452262) geopotential 19204
# (create_disp_files pid=1452262) relative_humidity 19034
# (create_disp_files pid=1452262) specific_humidity 19034
# (create_disp_files pid=1452264) 22845
# (create_disp_files pid=1452250) dew_point 41536
# (create_disp_files pid=1452250) geopotential 42644
# (create_disp_files pid=1452250) relative_humidity 41645
# (create_disp_files pid=1452267) 23415
# (create_disp_files pid=1452248) 23205
# (create_disp_files pid=1452250) specific_humidity 41534
# (create_disp_files pid=1452261) dew_point 19946
# (create_disp_files pid=1452261) geopotential 20059
# (create_disp_files pid=1452261) relative_humidity 19946
# (create_disp_files pid=1452261) specific_humidity 19946
# (create_disp_files pid=1452266) dew_point 42510
# (create_disp_files pid=1452266) geopotential 45742
# (create_disp_files pid=1452266) relative_humidity 42567
# (create_disp_files pid=1452266) specific_humidity 42510
# (create_disp_files pid=1452253) 23802
# (create_disp_files pid=1452256) dew_point 18897
# (create_disp_files pid=1452256) geopotential 18984
# (create_disp_files pid=1452256) relative_humidity 18897
# (create_disp_files pid=1452256) specific_humidity 18897
# (create_disp_files pid=1452254) dew_point 19986
# (create_disp_files pid=1452254) geopotential 20016
# (create_disp_files pid=1452254) relative_humidity 19985
# (create_disp_files pid=1452254) specific_humidity 19985
# (create_disp_files pid=1452264) dew_point 19261
# (create_disp_files pid=1452264) geopotential 20409
# (create_disp_files pid=1452264) relative_humidity 19258
# (create_disp_files pid=1452264) specific_humidity 19258
# (create_disp_files pid=1452265) dew_point 18010
# (create_disp_files pid=1452265) geopotential 18058
# (create_disp_files pid=1452265) relative_humidity 18010
# (create_disp_files pid=1452258) 26063
# (create_disp_files pid=1452258) 26258
# (create_disp_files pid=1452265) specific_humidity 18010
# (create_disp_files pid=1452257) 26406
# (create_disp_files pid=1452258) 26298
# (create_disp_files pid=1452267) dew_point 20837
# (create_disp_files pid=1452267) geopotential 21012
# (create_disp_files pid=1452267) relative_humidity 20837
# (create_disp_files pid=1452267) specific_humidity 20837
# (create_disp_files pid=1452257) 26422
# (create_disp_files pid=1452257) 26477
# (create_disp_files pid=1452255) 27199
# (create_disp_files pid=1452251) 27038
# (create_disp_files pid=1452258) dew_point 19896
# (create_disp_files pid=1452258) geopotential 21171
# (create_disp_files pid=1452260) 27459
# (create_disp_files pid=1452253) dew_point 20568
# (create_disp_files pid=1452258) relative_humidity 19896
# (create_disp_files pid=1452258) specific_humidity 19896
# (create_disp_files pid=1452253) geopotential 20662
# (create_disp_files pid=1452253) relative_humidity 20568
# (create_disp_files pid=1452253) specific_humidity 20568
# (create_disp_files pid=1452248) dew_point 20167
# (create_disp_files pid=1452248) geopotential 20344
# (create_disp_files pid=1452248) relative_humidity 20165
# (create_disp_files pid=1452248) specific_humidity 20165
# (create_disp_files pid=1452252) 27612
# (create_disp_files pid=1452255) dew_point 20237
# (create_disp_files pid=1452255) geopotential 20243
# (create_disp_files pid=1452255) relative_humidity 20237
# (create_disp_files pid=1452255) specific_humidity 20237
# (create_disp_files pid=1452251) dew_point 20183
# (create_disp_files pid=1452251) geopotential 20245
# (create_disp_files pid=1452251) relative_humidity 20183
# (create_disp_files pid=1452251) specific_humidity 20183
# (create_disp_files pid=1452257) dew_point 19541
# (create_disp_files pid=1452257) geopotential 19558
# (create_disp_files pid=1452257) relative_humidity 19540
# (create_disp_files pid=1452257) specific_humidity 19540
# (create_disp_files pid=1452259) 27730
# (create_disp_files pid=1452249) 27707
# (create_disp_files pid=1452252) dew_point 18001
# (create_disp_files pid=1452252) geopotential 18315
# (create_disp_files pid=1452260) dew_point 19034
# (create_disp_files pid=1452252) relative_humidity 18001
# (create_disp_files pid=1452252) specific_humidity 18001
# (create_disp_files pid=1452260) geopotential 19441
# (create_disp_files pid=1452260) relative_humidity 19034
# (create_disp_files pid=1452260) specific_humidity 19034
# (create_disp_files pid=1452262) 27962
# (create_disp_files pid=1452261) 33393
# (create_disp_files pid=1452259) dew_point 20159
# (create_disp_files pid=1452259) geopotential 20287
# (create_disp_files pid=1452259) relative_humidity 20159
# (create_disp_files pid=1452259) specific_humidity 20159
# (create_disp_files pid=1452249) dew_point 19711
# (create_disp_files pid=1452249) geopotential 21286
# (create_disp_files pid=1452261) dew_point 2311
# (create_disp_files pid=1452261) geopotential 5746
# (create_disp_files pid=1452261) relative_humidity 2300
# (create_disp_files pid=1452249) relative_humidity 19711
# (create_disp_files pid=1452249) specific_humidity 19711
# (create_disp_files pid=1452261) specific_humidity 2300
# (create_disp_files pid=1452256) 33815
# (create_disp_files pid=1452256) 33837
# (create_disp_files pid=1452262) dew_point 21518
# (create_disp_files pid=1452265) 34122
# (create_disp_files pid=1452262) geopotential 21816
# (create_disp_files pid=1452262) relative_humidity 21508
# (create_disp_files pid=1452262) specific_humidity 21508
# (create_disp_files pid=1452264) 34247
# (create_disp_files pid=1452256) dew_point 4049
# (create_disp_files pid=1452256) geopotential 9040
# (create_disp_files pid=1452256) relative_humidity 4045
# (create_disp_files pid=1452256) specific_humidity 4045
# (create_disp_files pid=1452267) 34858
# (create_disp_files pid=1452254) 40100
# (create_disp_files pid=1452254) 40179
# (create_disp_files pid=1452261) 60155
# (create_disp_files pid=1452265) dew_point 9674
# (create_disp_files pid=1452265) geopotential 10124
# (create_disp_files pid=1452265) relative_humidity 9672
# (create_disp_files pid=1452265) specific_humidity 9672
# (create_disp_files pid=1452261) dew_point 6191
# (create_disp_files pid=1452261) geopotential 6208
# (create_disp_files pid=1452261) relative_humidity 6190
# (create_disp_files pid=1452261) specific_humidity 6190
# (create_disp_files pid=1452258) 60715
# (create_disp_files pid=1452253) 62306
# (create_disp_files pid=1452267) dew_point 9879
# (create_disp_files pid=1452267) geopotential 9988
# (create_disp_files pid=1452267) relative_humidity 9869
# (create_disp_files pid=1452267) specific_humidity 9869
# (create_disp_files pid=1452248) 01400
# (create_disp_files pid=1452258) dew_point 6882
# (create_disp_files pid=1452258) geopotential 11051
# (create_disp_files pid=1452258) relative_humidity 11018
# (create_disp_files pid=1452258) specific_humidity 6878
# (create_disp_files pid=1452248) 08221
# (create_disp_files pid=1452253) dew_point 11230
# (create_disp_files pid=1452253) geopotential 12365
# (create_disp_files pid=1452253) relative_humidity 11225
# (create_disp_files pid=1452253) specific_humidity 11225
# (create_disp_files pid=1452255) 10393
# (create_disp_files pid=1452264) dew_point 21297
# (create_disp_files pid=1452264) geopotential 21416
# (create_disp_files pid=1452256) 10410
# (create_disp_files pid=1452248) dew_point 0
# (create_disp_files pid=1452248) geopotential 12408
# (create_disp_files pid=1452248) relative_humidity 0
# (create_disp_files pid=1452248) specific_humidity 0
# (create_disp_files pid=1452261) 10548
# (create_disp_files pid=1452264) relative_humidity 21297
# (create_disp_files pid=1452264) specific_humidity 21297
# (create_disp_files pid=1452257) 16045
# (create_disp_files pid=1452251) 22522
# (create_disp_files pid=1452265) 34172
# (create_disp_files pid=1452252) 34467
# (create_disp_files pid=1452254) dew_point 11725
# (create_disp_files pid=1452254) geopotential 12103
# (create_disp_files pid=1452254) relative_humidity 11724
# (create_disp_files pid=1452254) specific_humidity 11724
# (create_disp_files pid=1452260) 34731
# (create_disp_files pid=1452267) 37011
# (create_disp_files pid=1452251) dew_point 20427
# (create_disp_files pid=1452251) geopotential 20525
# (create_disp_files pid=1452251) relative_humidity 20427
# (create_disp_files pid=1452251) specific_humidity 20427
# (create_disp_files pid=1452252) dew_point 20168
# (create_disp_files pid=1452252) geopotential 20432
# (create_disp_files pid=1452252) relative_humidity 20160
# (create_disp_files pid=1452252) specific_humidity 20160
# (create_disp_files pid=1452265) dew_point 20466
# (create_disp_files pid=1452265) geopotential 20549
# (create_disp_files pid=1452265) relative_humidity 20466
# (create_disp_files pid=1452265) specific_humidity 20466
# (create_disp_files pid=1452260) dew_point 19076
# (create_disp_files pid=1452260) geopotential 19696
# (create_disp_files pid=1452260) relative_humidity 19075
# (create_disp_files pid=1452260) specific_humidity 19075
# (create_disp_files pid=1452267) dew_point 19154
# (create_disp_files pid=1452267) geopotential 19166
# (create_disp_files pid=1452267) relative_humidity 19151
# (create_disp_files pid=1452267) specific_humidity 19151
# (create_disp_files pid=1452257) dew_point 22334
# (create_disp_files pid=1452257) geopotential 22607
# (create_disp_files pid=1452257) relative_humidity 22341
# (create_disp_files pid=1452257) specific_humidity 22333
# (create_disp_files pid=1452256) dew_point 28583
# (create_disp_files pid=1452256) geopotential 29812
# (create_disp_files pid=1452256) relative_humidity 28583
# (create_disp_files pid=1452256) specific_humidity 28583
# (create_disp_files pid=1452261) dew_point 25054
# (create_disp_files pid=1452261) geopotential 27039
# (create_disp_files pid=1452261) relative_humidity 25054
# (create_disp_files pid=1452261) specific_humidity 25054
# (create_disp_files pid=1452255) dew_point 44858
# (create_disp_files pid=1452255) geopotential 46112
# (create_disp_files pid=1452255) relative_humidity 44858
# (create_disp_files pid=1452255) specific_humidity 44858
