# %%
import CUON_trends
import json
with open("trend_notebook_info.json", "r") as read_file:
    trend_notebook_info = json.load(read_file)
# Out:
# no config found

# %% [markdown]
# # Trends plots

# %%
CUON_trends.show_trend_map(trend_notebook_info['file'], trend_notebook_info['label'], trend_notebook_info['c_bar'], c_bar_red_top=True)
