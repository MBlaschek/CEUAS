# %%
import glob
from IPython.display import Image

# %% [markdown]
# # Relative Humidity

# %%
imgs = sorted(glob.glob('./cuon_trends/polyfit_trends_rh*.png'))
for i in imgs:
    display(Image(filename = i, width="1250"))

# %% [markdown]
# # Dewpoint

# %%
imgs = sorted(glob.glob('./cuon_trends/polyfit_trends_dp*.png'))
for i in imgs:
    display(Image(filename = i, width="1250"))
